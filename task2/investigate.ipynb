# %%
import pandas as pd

data = pd.read_csv(r"D:\S3\bayesian_opt_results\bayes_results_sorted_with_recalls.csv")

# %%
iwannasee = data[['recall_fire','recall_nofire']]

# %%
iwannasee = iwannasee[(iwannasee['recall_fire'] > 0.8) & (iwannasee['recall_nofire'] > 0.8)]

# %%
iwannasee.head(10)
# Out:
#     recall_fire  recall_nofire
# 29     0.865535       0.803407
# 30     0.872063       0.818754
# 32     0.868146       0.820553
# 33     0.834204       0.827777

# %%
iwannasee.to_csv(r"D:\S3\rapport data_mining\sorted.csv")
